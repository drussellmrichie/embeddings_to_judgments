# %%
import pandas as pd
from gensim.models import KeyedVectors
from sklearn.preprocessing import normalize
import numpy as np
import re

# %%
wv_from_bin = KeyedVectors.load_word2vec_format(fname="GoogleNews-vectors-negative300.bin", binary=True)  # C binary format

# %% [markdown]
# # LIWC

# %%
liwc = pd.read_csv('data/LIWC - full.csv', index_col=0).T.reset_index()
liwc.index.name = ''
liwc.columns = ['Function'] + list(liwc.columns[1:])
liwc.head()
# Out:
#      Function   Pronoun Ppron       I         We     You SheHe        They  \
#
# 0           a   another    he     i'd      let's    ily*    he      their*
# 1       about   anybod*  he'd  i'd've       lets    thee  he'd        them
# 2       above   anymore  he's    i'll        our   thine  he's    themself
# 3  absolutely   anyone*   her     i'm       ours    thou   her  themselves
# 4         abt  anything  hers    i've  ourselves  thoust  hers        they
#
#       Ipron Article     ...            Money       Relig     Death Informal   \
#                         ...
# 0   another       a     ...         account*  afterlife*     alive        (:
# 1   anybod*      an     ...          accrue*     agnost*   assass*        (;
# 2   anymore     the     ...       affordable        alla   autops*        ):
# 3   anyone*     NaN     ...              atm      allah*   behead*        /:
# 4  anything     NaN     ...             atms      altar*  bereave*      4ev*
#
#        Swear Netspeak      Assent Nonflu     Filler    Cognitive
#
# 0         af       (:  absolutely     ah    anyway*    abnormal*
# 1       arse       (;       agree   ahh*       blah     could've
# 2  arsehole*       ):          ah     er      dunno         hazy
# 3      arses       /:       aight    hm*        idk      need'nt
# 4        asf     4ev*    alright*    huh  idontknow  secretively
#
# [5 rows x 74 columns]

# %% [markdown]
# This cleaning procedure should generally help, but it will also introduce a little noise. For example i'd becomes id, which is a different word.

# %%
def try_clean(cell):
    try:
        word = ''.join(char for char in cell if char.isalpha()) #cell.replace('*','') 
        word = np.NaN if word == 'Unnamed' else word # need this because Unnamed: 0 is in the Function column after read_csv
        return word
    except:
        return cell

liwc = liwc.applymap(try_clean)
liwc.head()
# Out:
#      Function   Pronoun Ppron     I         We     You SheHe        They  \
#
# 0           a   another    he    id       lets     ily    he       their
# 1       about    anybod   hed  idve       lets    thee   hed        them
# 2       above   anymore   hes   ill        our   thine   hes    themself
# 3  absolutely    anyone   her    im       ours    thou   her  themselves
# 4         abt  anything  hers   ive  ourselves  thoust  hers        they
#
#       Ipron Article     ...            Money      Relig    Death Informal   \
#                         ...
# 0   another       a     ...          account  afterlife    alive
# 1    anybod      an     ...           accrue     agnost   assass
# 2   anymore     the     ...       affordable       alla   autops
# 3    anyone     NaN     ...              atm      allah   behead
# 4  anything     NaN     ...             atms      altar  bereave        ev
#
#       Swear Netspeak      Assent Nonflu     Filler    Cognitive
#
# 0        af           absolutely     ah     anyway     abnormal
# 1      arse                agree    ahh       blah      couldve
# 2  arsehole                   ah     er      dunno         hazy
# 3     arses                aight     hm        idk       neednt
# 4       asf       ev     alright    huh  idontknow  secretively
#
# [5 rows x 74 columns]

# %%
liwc.tail()
# Out:
#      Function Pronoun Ppron    I   We  You SheHe They Ipron Article    ...     \
#                                                                        ...
# 1411      NaN     NaN   NaN  NaN  NaN  NaN   NaN  NaN   NaN     NaN    ...
# 1412      NaN     NaN   NaN  NaN  NaN  NaN   NaN  NaN   NaN     NaN    ...
# 1413      NaN     NaN   NaN  NaN  NaN  NaN   NaN  NaN   NaN     NaN    ...
# 1414      NaN     NaN   NaN  NaN  NaN  NaN   NaN  NaN   NaN     NaN    ...
# 1415      NaN     NaN   NaN  NaN  NaN  NaN   NaN  NaN   NaN     NaN    ...
#
#      Money Relig Death Informal  Swear Netspeak Assent Nonflu Filler Cognitive
#
# 1411   NaN   NaN   NaN       NaN   NaN      NaN    NaN    NaN    NaN       NaN
# 1412   NaN   NaN   NaN       NaN   NaN      NaN    NaN    NaN    NaN       NaN
# 1413   NaN   NaN   NaN       NaN   NaN      NaN    NaN    NaN    NaN       NaN
# 1414   NaN   NaN   NaN       NaN   NaN      NaN    NaN    NaN    NaN       NaN
# 1415   NaN   NaN   NaN       NaN   NaN      NaN    NaN    NaN    NaN       NaN
#
# [5 rows x 74 columns]

# %%
vectors_in_cells = liwc.applymap(lambda x: wv_from_bin[x] if x in wv_from_bin else np.nan)
vectors_in_cells.head()
# Out:
#                                             Function  \
#
# 0                                                NaN
# 1  [0.20214844, -0.08105469, 0.18359375, -0.13671...
# 2  [-0.12402344, -0.20605469, -0.08886719, 0.2656...
# 3  [-0.043701172, -0.27929688, 0.09277344, -0.073...
# 4  [-0.18261719, 0.1796875, 0.14160156, 0.1137695...
#
#                                              Pronoun  \
#
# 0  [0.19433594, -0.01965332, 0.091796875, 0.10449...
# 1                                                NaN
# 2  [0.15820312, -0.13183594, -0.088378906, 0.2373...
# 3  [0.16796875, -0.26171875, 0.010620117, 0.14550...
# 4  [0.07080078, -0.03491211, 0.06542969, 0.058837...
#
#                                                Ppron  \
#
# 0  [0.19238281, 0.12792969, -0.019165039, -0.0292...
# 1  [-0.13476562, 0.15820312, -0.28710938, -0.0756...
# 2  [0.0390625, 0.078125, -0.10644531, 0.15820312,...
# 3  [0.14648438, -0.013793945, -0.019165039, -0.04...
# 4  [-0.022460938, -0.22167969, 0.046875, 0.214843...
#
#                                                    I  \
#
# 0  [0.29492188, -0.12109375, 0.0006828308, 0.2207...
# 1                                                NaN
# 2  [-0.0030975342, 0.07324219, -0.26757812, 0.119...
# 3  [-0.036621094, 0.014526367, 0.03515625, 0.2304...
# 4  [-0.41210938, 0.18847656, -0.234375, 0.296875,...
#
#                                                   We  \
#
# 0  [0.19824219, -0.0026245117, 0.123046875, 0.075...
# 1  [0.19824219, -0.0026245117, 0.123046875, 0.075...
# 2  [-0.19824219, 0.17285156, 0.08544922, 0.371093...
# 3  [-0.14257812, 0.06298828, 0.07910156, 0.431640...
# 4  [0.07910156, 0.24316406, 0.24121094, 0.3164062...
#
#                                                  You  \
#
# 0  [0.012939453, -0.018310547, -0.026000977, 0.12...
# 1  [0.07128906, 0.04638672, -0.11230469, 0.126953...
# 2  [0.068847656, 0.034179688, -0.15332031, 0.3222...
# 3  [0.22949219, 0.33984375, 0.23730469, 0.0751953...
# 4                                                NaN
#
#                                                SheHe  \
#
# 0  [0.19238281, 0.12792969, -0.019165039, -0.0292...
# 1  [-0.13476562, 0.15820312, -0.28710938, -0.0756...
# 2  [0.0390625, 0.078125, -0.10644531, 0.15820312,...
# 3  [0.14648438, -0.013793945, -0.019165039, -0.04...
# 4  [-0.022460938, -0.22167969, 0.046875, 0.214843...
#
#                                                 They  \
#
# 0  [0.07324219, 0.19628906, 0.0005187988, 0.14355...
# 1  [0.03491211, 0.08496094, 0.0625, 0.140625, -0....
# 2  [0.28515625, -0.14355469, 0.14160156, 0.144531...
# 3  [0.16699219, 0.15917969, 0.05078125, 0.0498046...
# 4  [0.064453125, 0.036132812, 0.03857422, 0.09472...
#
#                                                Ipron  \
#
# 0  [0.19433594, -0.01965332, 0.091796875, 0.10449...
# 1                                                NaN
# 2  [0.15820312, -0.13183594, -0.088378906, 0.2373...
# 3  [0.16796875, -0.26171875, 0.010620117, 0.14550...
# 4  [0.07080078, -0.03491211, 0.06542969, 0.058837...
#
#                                              Article  \
#
# 0                                                NaN
# 1  [0.12597656, 0.19042969, 0.06982422, 0.0722656...
# 2  [0.080078125, 0.10498047, 0.049804688, 0.05346...
# 3                                                NaN
# 4                                                NaN
#
#                          ...                          \
#                          ...
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                                Money  \
#
# 0  [-0.025634766, -0.0046081543, 0.030395508, -0....
# 1  [0.12402344, 0.07714844, -0.17773438, 0.324218...
# 2  [-0.041503906, -0.13183594, -0.19824219, 0.013...
# 3  [-0.31054688, 0.15429688, -0.25195312, 0.04809...
# 4                                                NaN
#
#                                                Relig  \
#
# 0  [0.33398438, -0.13769531, -0.24414062, 0.19824...
# 1                                                NaN
# 2  [0.037109375, 0.06933594, 0.14453125, 0.209960...
# 3  [0.22265625, 0.114746094, 0.2578125, 0.2832031...
# 4  [0.115234375, 0.2578125, -0.17675781, 0.240234...
#
#                                                Death  \
#
# 0  [0.051757812, 0.018432617, 0.1484375, -0.03637...
# 1                                                NaN
# 2                                                NaN
# 3  [-0.16113281, -0.22363281, 0.39648438, 0.12695...
# 4  [0.072265625, 0.040527344, -0.041503906, 0.102...
#
#                                            Informal   \
#
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [-0.23242188, 0.08886719, 0.10839844, 0.095703...
#
#                                                Swear  \
#
# 0  [-0.107421875, -0.02709961, 0.107421875, 0.091...
# 1                                                NaN
# 2  [0.25585938, -0.3359375, 0.18261719, -0.005645...
# 3                                                NaN
# 4  [0.11279297, -0.08691406, 0.012634277, 0.11474...
#
#                                             Netspeak  \
#
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [-0.23242188, 0.08886719, 0.10839844, 0.095703...
#
#                                               Assent  \
#
# 0  [-0.043701172, -0.27929688, 0.09277344, -0.073...
# 1  [-0.03857422, 0.026245117, 0.19042969, 0.12109...
# 2  [-0.1640625, 0.19726562, 0.19921875, 0.1884765...
# 3  [-0.12988281, -0.055908203, 0.036621094, 0.205...
# 4  [0.140625, -0.026733398, 0.08105469, 0.125, -0...
#
#                                               Nonflu  \
#
# 0  [-0.1640625, 0.19726562, 0.19921875, 0.1884765...
# 1  [0.071777344, 0.14160156, 0.15820312, 0.300781...
# 2  [0.044433594, 0.1875, -0.05493164, 0.07763672,...
# 3  [-0.017211914, 0.01965332, 0.19042969, 0.42578...
# 4  [0.2734375, 0.14160156, 0.057373047, 0.4277343...
#
#                                               Filler  \
#
# 0  [0.13085938, -0.07910156, 0.026000977, 0.22949...
# 1  [-0.03491211, 0.20019531, 0.106933594, 0.14160...
# 2  [0.06933594, -0.15039062, 0.14941406, 0.332031...
# 3  [-0.23046875, -0.060546875, 0.05102539, 0.3828...
# 4                                                NaN
#
#                                            Cognitive
#
# 0  [-0.17578125, 0.14746094, -0.015625, -0.018798...
# 1  [-0.052001953, -0.017944336, -0.010559082, 0.1...
# 2  [0.2734375, -0.042236328, 0.16503906, 0.074707...
# 3                                                NaN
# 4  [-0.035888672, -0.17480469, -0.083984375, -0.0...
#
# [5 rows x 74 columns]

# %%
liwc_avg_vecs = vectors_in_cells.apply(np.mean)
liwc_avg_vecs
# Out:
#      Function   Pronoun     Ppron         I        We       You     SheHe  \
# 0    0.039440  0.051351  0.048744 -0.014726 -0.046326  0.082492  0.124512
# 1   -0.006557  0.026285  0.038816  0.009051  0.037608  0.070349  0.017023
# 2    0.027752  0.021411  0.018129  0.015066 -0.022882  0.074504 -0.055748
# 3    0.148285  0.190776  0.205819  0.220933  0.210083  0.280735  0.009247
# 4   -0.066668 -0.070047 -0.057547 -0.082427 -0.046621 -0.056229  0.013390
# 5    0.027370  0.051375  0.064774  0.112362 -0.077609  0.147366  0.010986
# 6    0.015041 -0.024560 -0.056900 -0.056887  0.029751 -0.095488 -0.059723
# 7   -0.085990 -0.048134 -0.042973 -0.092443 -0.084195 -0.023809 -0.043327
# 8    0.064208 -0.028507 -0.071937 -0.014936 -0.126305 -0.092043 -0.056402
# 9    0.062922  0.015395  0.012003  0.029074  0.035990  0.036082 -0.098915
# 10  -0.065997 -0.054745 -0.048572 -0.109411 -0.065679 -0.080137  0.071033
# 11  -0.151488 -0.170078 -0.185568 -0.205195 -0.138062 -0.154872 -0.248333
# 12  -0.077635 -0.092453 -0.105054 -0.132882  0.054916 -0.205942 -0.029567
# 13   0.005844 -0.002465  0.011011 -0.069494  0.054268  0.038615 -0.006104
# 14  -0.111879 -0.136854 -0.127802 -0.066794 -0.091873 -0.147497 -0.202890
# 15   0.078673  0.115138  0.124292  0.100087  0.089485  0.154876  0.169680
# 16   0.059062  0.061930  0.076003  0.103329  0.128977  0.074934 -0.031441
# 17   0.122973  0.116955  0.133566  0.184025  0.205800  0.053494  0.135742
# 18   0.009193  0.037856  0.035501  0.012549 -0.023376  0.103411 -0.002837
# 19  -0.044019 -0.043038 -0.021410 -0.083062  0.023570 -0.013202 -0.005775
# 20  -0.024899 -0.015908 -0.009187 -0.069469 -0.057668  0.062586 -0.013359
# 21  -0.012236  0.018789  0.028333  0.065408  0.033890 -0.004875  0.102295
# 22   0.087681  0.147350  0.187094  0.283720  0.083715  0.287534  0.060272
# 23  -0.047309 -0.064806 -0.060937 -0.008071 -0.016703 -0.088573 -0.062395
# 24   0.034855 -0.015050 -0.046057 -0.102263  0.142807 -0.112648 -0.082103
#
#          They     Ipron   Article    ...         Money     Relig     Death  \
# 0    0.054244  0.053011  0.103027    ...      0.064965  0.165077  0.127482
# 1    0.035245  0.004571  0.147705    ...      0.011034  0.014858  0.153382
# 2    0.032673  0.025068  0.059814    ...     -0.044619  0.099840  0.137861
# 3    0.272283  0.159922  0.062866    ...      0.167710  0.172983  0.155117
# 4   -0.133301 -0.090539 -0.143066    ...      0.048566 -0.029042 -0.029057
# 5    0.024481  0.026549 -0.046509    ...      0.009038  0.046002  0.045171
# 6   -0.065385  0.035267  0.044556    ...      0.073200  0.026835  0.112012
# 7    0.045288 -0.055158 -0.097656    ...     -0.063477 -0.045319 -0.147449
# 8   -0.063277  0.045333  0.043457    ...      0.143938  0.057761  0.201386
# 9    0.055779  0.018879 -0.049866    ...      0.073052  0.130870  0.123869
# 10  -0.021837 -0.063240 -0.002686    ...     -0.024069 -0.020312  0.160700
# 11  -0.171498 -0.145827 -0.090576    ...      0.010564 -0.129676 -0.147041
# 12  -0.107910 -0.069147 -0.050934    ...     -0.023741 -0.143205 -0.151049
# 13   0.061329 -0.023907  0.052734    ...      0.106046  0.153192  0.169315
# 14  -0.112873 -0.153331 -0.067627    ...     -0.115321 -0.095078 -0.014849
# 15   0.049893  0.102160 -0.033859    ...      0.163533  0.116157 -0.003947
# 16   0.132213  0.038683  0.045380    ...      0.048308 -0.046040 -0.054310
# 17   0.171953  0.087832 -0.017029    ...      0.091944  0.044019  0.102219
# 18   0.034280  0.043813 -0.036255    ...      0.045698 -0.012102  0.033426
# 19  -0.018685 -0.082048 -0.007202    ...      0.029609 -0.108548 -0.063569
# 20  -0.041238 -0.027690  0.034912    ...      0.035714  0.219564  0.140886
# 21  -0.068154  0.000079 -0.010742    ...     -0.001433  0.006000 -0.061223
# 22   0.099339  0.081068 -0.153320    ...      0.098594  0.135527  0.065784
# 23  -0.131647 -0.065005 -0.048267    ...     -0.015287 -0.095761 -0.050828
# 24   0.046143  0.041102 -0.020996    ...      0.013782  0.033725  0.019990
# 25   0.041238  0.005729 -0.025269    ...      0.026749 -0.055182 -0.072002
# 26  -0.086126 -0.083502 -0.054077    ...     -0.079450 -0.114899 -0.087757
# 27   0.005604  0.051279  0.198242    ...      0.057638  0.042482 -0.094318
# 28  -0.040477 -0.016351  0.085320    ...     -0.039306  0.052961  0.065255
# 29  -0.160667 -0.060673  0.128906    ...     -0.034505 -0.165756 -0.213157
# ..        ...       ...       ...    ...           ...       ...       ...
# 270  0.055509 -0.003080  0.062134    ...     -0.071597 -0.088234  0.016727
# 271  0.219727  0.067497  0.078125    ...      0.114555  0.088091  0.001291
# 272  0.083820  0.126097  0.062805    ...     -0.020400  0.048581  0.054022
# 273  0.215643  0.075769 -0.013916    ...      0.013977  0.132760 -0.031774
# 274  0.049391 -0.011078  0.076294    ...      0.047851  0.111851  0.121480
# 275 -0.053397 -0.009129 -0.024536    ...      0.004484 -0.103111 -0.009348
# 276 -0.028026 -0.009955 -0.067749    ...     -0.049284 -0.092343 -0.022639
# 288   0.016423  0.035985  0.006787  0.021448 -0.018523  0.025879   0.071137
# 289  -0.002798 -0.054400  0.001416  0.081803  0.159392  0.043610   0.024696
# 290   0.101200  0.114973  0.104542  0.037450  0.015954  0.108536  -0.111311
# 291   0.141666  0.146409  0.151798  0.134785  0.115697  0.131592   0.051465
# 292  -0.127384 -0.187613 -0.100636 -0.033081 -0.066962 -0.091042  -0.037963
# 293   0.022101  0.040136  0.026755  0.024634  0.022237  0.055054   0.029007
# 294  -0.110948 -0.174204 -0.082842 -0.096137 -0.079839 -0.062210  -0.060218
# 295  -0.153895 -0.122832 -0.183840 -0.117275 -0.145540 -0.177516  -0.012635
# 296  -0.064884 -0.018824 -0.104163 -0.025144 -0.058959 -0.042586  -0.001738
# 297  -0.115470 -0.091868 -0.129945 -0.132015 -0.076236 -0.090332  -0.065859
# 298  -0.124388 -0.168568 -0.103940 -0.082062 -0.056377 -0.088348   0.020649
# 299   0.086819  0.061121  0.116261  0.062354  0.083501  0.063751   0.047353
#
# [300 rows x 74 columns]

# %%
# liwc_avg_vecs.to_csv('data/liwc_avg_vecs.csv', index=False)

# %% [markdown]
# # Harvard General Inquirer dictionary

# %%
inq = pd.read_excel('data/inquirerbasic.xls', index_col=0)
inq.head()
# Out:
#             Source Positiv  Negativ Pstv Affil  Ngtv Hostile Strong Power  \
# Entry
# A            H4Lvd     NaN      NaN  NaN   NaN   NaN     NaN    NaN   NaN
# ABANDON      H4Lvd     NaN  Negativ  NaN   NaN  Ngtv     NaN    NaN   NaN
# ABANDONMENT     H4     NaN  Negativ  NaN   NaN   NaN     NaN    NaN   NaN
# ABATE        H4Lvd     NaN  Negativ  NaN   NaN   NaN     NaN    NaN   NaN
# ABATEMENT      Lvd     NaN      NaN  NaN   NaN   NaN     NaN    NaN   NaN
#
#              Weak                        ...                         Anomie  \
# Entry                                    ...
# A             NaN                        ...                            NaN
# ABANDON      Weak                        ...                            NaN
# ABANDONMENT  Weak                        ...                            NaN
# ABATE         NaN                        ...                            NaN
# ABATEMENT     NaN                        ...                            NaN
#
#             NegAff PosAff SureLw   If NotLw TimeSpc FormLw  Othtags  \
# Entry
# A              NaN    NaN    NaN  NaN   NaN     NaN    NaN  DET ART
# ABANDON        NaN    NaN    NaN  NaN   NaN     NaN    NaN     SUPV
# ABANDONMENT    NaN    NaN    NaN  NaN   NaN     NaN    NaN     Noun
# ABATE          NaN    NaN    NaN  NaN   NaN     NaN    NaN     SUPV
# ABATEMENT      NaN    NaN    NaN  NaN   NaN     NaN    NaN     Noun
#
#                                                        Defined
# Entry
# A            | article: Indefinite singular article--some o...
# ABANDON                                                      |
# ABANDONMENT                                                  |
# ABATE                                                        |
# ABATEMENT                                                  NaN
#
# [5 rows x 185 columns]

# %%
inq = inq.drop(['Source', 'Othtags', 'Defined'], axis='columns')
inq.head()
# Out:
#             Positiv  Negativ Pstv Affil  Ngtv Hostile Strong Power  Weak  \
# Entry
# A               NaN      NaN  NaN   NaN   NaN     NaN    NaN   NaN   NaN
# ABANDON         NaN  Negativ  NaN   NaN  Ngtv     NaN    NaN   NaN  Weak
# ABANDONMENT     NaN  Negativ  NaN   NaN   NaN     NaN    NaN   NaN  Weak
# ABATE           NaN  Negativ  NaN   NaN   NaN     NaN    NaN   NaN   NaN
# ABATEMENT       NaN      NaN  NaN   NaN   NaN     NaN    NaN   NaN   NaN
#
#             Submit  ...   PtLw Nation Anomie NegAff PosAff SureLw   If NotLw  \
# Entry               ...
# A              NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN  NaN   NaN
# ABANDON        NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN  NaN   NaN
# ABANDONMENT    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN  NaN   NaN
# ABATE          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN  NaN   NaN
# ABATEMENT      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN  NaN   NaN
#
#             TimeSpc FormLw
# Entry
# A               NaN    NaN
# ABANDON         NaN    NaN
# ABANDONMENT     NaN    NaN
# ABATE           NaN    NaN
# ABATEMENT       NaN    NaN
#
# [5 rows x 182 columns]

# %%
inq.loc[False].head()
# Out:
# Positiv        NaN
# Negativ    Negativ
# Pstv           NaN
# Affil          NaN
# Ngtv          Ngtv
# dtype: object

# %% [markdown]
# That's some data entry or encoding error. We need to replace that row with the *string* `'False'`

# %%
as_list = inq.index.tolist()
idx = as_list.index(False)
as_list[idx] = 'False'
inq.index = as_list

# %%
assert False not in inq.index

# %%
inq.loc['False'].head()
# Out:
# Positiv        NaN
# Negativ    Negativ
# Pstv           NaN
# Affil          NaN
# Ngtv          Ngtv
# Name: False, dtype: object

# %%
stacked_inq = inq.stack()
stacked_inq.head()
# Out:
# ABANDON  Negativ    Negativ
#          Ngtv          Ngtv
#          Weak          Weak
#          Fail          Fail
#          IAV            IAV
# dtype: object

# %%
stacked_inq = stacked_inq.reset_index().drop(0, axis='columns')
stacked_inq.columns = ['word','category']
stacked_inq.head()
# Out:
#       word category
# 0  ABANDON  Negativ
# 1  ABANDON     Ngtv
# 2  ABANDON     Weak
# 3  ABANDON     Fail
# 4  ABANDON      IAV

# %%
regex = re.compile('[^a-zA-Z]')
#First parameter is the replacement, second parameter is your input string
regex.sub('', 'ab3d*E')
# Out:
# 'abdE'

# %%
def clean_words(word):
    word = regex.sub('', word.lower())
    return word

stacked_inq['word'] = stacked_inq['word'].apply(clean_words)
stacked_inq.head()
# Out:
#       word category
# 0  abandon  Negativ
# 1  abandon     Ngtv
# 2  abandon     Weak
# 3  abandon     Fail
# 4  abandon      IAV

# %%
def average_vectors(words):
    words = words.word
    vecs = []
    for word in words:
        try:
            vec = wv_from_bin[word]
            vecs.append(vec)
        except KeyError:
            continue
    return pd.DataFrame(vecs).mean(axis=0)

# %%
inq_avg_vectors = stacked_inq.groupby('category').apply(average_vectors).T
inq_avg_vectors.head()
# Out:
# category       ABS       ANI      Abs@    Academ    Active   AffGain  \
# 0         0.047323  0.029427  0.090752  0.053920  0.037450  0.059068
# 1         0.051974  0.104235  0.033096  0.004647  0.060734 -0.021589
# 2         0.015816 -0.191244  0.023970  0.069611  0.004073  0.030237
# 3         0.100709  0.090906  0.117980  0.141519  0.048712  0.124644
# 4        -0.044055 -0.020440 -0.063909  0.066524 -0.071443 -0.092868
#
# category   AffLoss    AffOth     AffPt    AffTot    ...      WlbPsyc  \
# 0         0.082395  0.098802  0.074279  0.083579    ...     0.154763
# 1         0.043723  0.022277 -0.074794 -0.012202    ...     0.049124
# 2        -0.246097 -0.000100  0.005405 -0.007716    ...     0.026844
# 3         0.161871  0.124055  0.079389  0.113175    ...     0.049746
# 4        -0.148593 -0.094935  0.045352 -0.059646    ...    -0.110401
#
# category     WlbPt    WlbTot    WltOth     WltPt    WltTot   WltTran  \
# 0         0.034029  0.069767  0.058066  0.066566  0.061390  0.073435
# 1         0.018446  0.078530  0.032591 -0.027608  0.023562  0.027835
# 2        -0.046716 -0.005397 -0.059825 -0.103164 -0.068362 -0.074830
# 3         0.119494  0.078296  0.098404  0.069943  0.096440  0.106396
# 4        -0.109217 -0.106026  0.037566  0.030673  0.034472  0.026721
#
# category      Work       Yes       You
# 0         0.015147  0.057469  0.205105
# 1         0.093043 -0.002935  0.098524
# 2        -0.015966  0.045119  0.113444
# 3         0.033535  0.161345  0.294054
# 4        -0.065664 -0.091167 -0.106852
#
# [5 rows x 182 columns]

# %% [markdown]
# # Combine dictionaries' average vector dataframes

# %%
all_dictionaries_avgs = pd.concat([inq_avg_vectors, liwc_avg_vecs], axis='columns').T
all_dictionaries_avgs.head()
# Out:
#              0         1         2         3         4         5         6    \
# ABS     0.047323  0.051974  0.015816  0.100709 -0.044055 -0.013068  0.089823
# ANI     0.029427  0.104235 -0.191244  0.090906 -0.020440 -0.028862  0.012906
# Abs@    0.090752  0.033096  0.023970  0.117980 -0.063909  0.026130  0.112878
# Academ  0.053920  0.004647  0.069611  0.141519  0.066524  0.062273  0.128890
# Active  0.037450  0.060734  0.004073  0.048712 -0.071443  0.014378  0.060926
#
#              7         8         9      ...          290       291       292  \
# ABS    -0.116081  0.100341  0.082088    ...    -0.092534  0.014969 -0.094077
# ANI     0.018099  0.057349  0.041140    ...    -0.140927  0.056619 -0.091317
# Abs@   -0.121309  0.098919  0.064893    ...    -0.133848  0.017571 -0.071422
# Academ -0.092114  0.028991 -0.076046    ...    -0.120987 -0.000318 -0.150794
# Active -0.042278  0.078379  0.068554    ...    -0.011435  0.076758 -0.077064
#
#              293       294       295       296       297       298       299
# ABS    -0.065393 -0.036495 -0.021092 -0.003979 -0.027713 -0.005736  0.007130
# ANI     0.034088  0.065352  0.075121  0.043407  0.132303 -0.028511  0.094875
# Abs@   -0.089449 -0.056986  0.018606  0.062237 -0.039359 -0.015719  0.028384
# Academ  0.013228 -0.014078 -0.002920  0.001430 -0.032383  0.080872  0.049225
# Active  0.024897 -0.072333 -0.042771 -0.006919 -0.072431  0.024453 -0.001164
#
# [5 rows x 300 columns]

# %%
all_dictionaries_avgs = pd.DataFrame(normalize(all_dictionaries_avgs), index=all_dictionaries_avgs.index)

# %%
all_dictionaries_avgs.to_csv('data/all_dictionaries_avg_vectors.csv')
